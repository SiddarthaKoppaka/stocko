# %% [markdown]
# # Data Ingestion

# %%
from stock_manager.config import load_config
from stock_manager.data.ingestion import ingest_market_data

outputs = ingest_market_data(load_config('configs/data_alpaca_yfinance_fred.yaml'))
outputs

# %% [markdown]
# # Qlib Dataset Build

# %%
from stock_manager.config import load_config
from stock_manager.qlib import build_qlib_dataset

outputs = build_qlib_dataset(load_config('configs/qlib_lightgbm_alpha158.yaml'))
outputs

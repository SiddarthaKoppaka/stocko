# %% [markdown]
# # Backtest and Compare Models

# %%
from stock_manager.backtest import compare_models
from stock_manager.config import load_config

outputs = compare_models(load_config('configs/backtest_compare.yaml'))
outputs

# %% [markdown]
# # Train StockMixer Adapter

# %%
from stock_manager.config import load_config
from stock_manager.models import train_from_config

outputs = train_from_config(load_config('configs/qlib_stockmixer.yaml'))
outputs

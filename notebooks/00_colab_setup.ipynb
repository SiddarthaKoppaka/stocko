# %% [markdown]
# # Colab Setup
# Mount Drive, clone/pull the repo, install dependencies, and verify imports.

# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
# %cd /content
# !git clone https://github.com/YOUR_ORG/stock-manager.git
# %cd /content/stock-manager
# !pip install -e '.[all]'

# %%
import os

os.environ.setdefault('STOCK_MANAGER_DATA_DIR', '/content/drive/MyDrive/Stock_manager/data')
os.environ.setdefault('STOCK_MANAGER_MODEL_DIR', '/content/drive/MyDrive/Stock_manager/models')
os.environ.setdefault('STOCK_MANAGER_REPORT_DIR', '/content/drive/MyDrive/Stock_manager/reports')
import stock_manager

print(stock_manager.__version__)
